# %%
import pandas as pd
from main_process import DataInput
pd.set_option('display.max_columns', None)

# Load data
input_regression_data = DataInput('regression').process_data()

input_regression_data.head()
# Out:
# 2025-03-15 00:04:09.405 | INFO     | main_process:process_data:26 - Loading data
# 2025-03-15 00:04:09.429 | INFO     | data_loader:load_data:34 - Loading data from /Users/theopenguino/Downloads/aiip5-Er-Qi-Yang-227J/data/agri.db
# Loading data from /Users/theopenguino/Downloads/aiip5-Er-Qi-Yang-227J/data/agri.db
# 2025-03-15 00:04:09.765 | INFO     | data_loader:load_data:58 - Data loaded successfully with shape: (57489, 15)
# 2025-03-15 00:04:09.766 | DEBUG    | data_loader:load_data:59 - Columns in data: ['System Location Code', 'Previous Cycle Plant Type', 'Plant Type', 'Plant Stage', 'Temperature Sensor (°C)', 'Humidity Sensor (%)', 'Light Intensity Sensor (lux)', 'CO2 Sensor (ppm)', 'EC Sensor (dS/m)', 'O2 Sensor (ppm)', 'Nutrient N Sensor (ppm)', 'Nutrient P Sensor (ppm)', 'Nutrient K Sensor (ppm)', 'pH Sensor', 'Water Level Sensor (mm)']
# 2025-03-15 00:04:09.766 | INFO     | main_process:process_data:28 - Cleaning data
# ...

# %%
input_classification_data = DataInput('classification').process_data()

input_classification_data.head()
# Out:
# 2025-03-15 00:04:18.387 | INFO     | main_process:process_data:26 - Loading data
# 2025-03-15 00:04:18.412 | INFO     | data_loader:load_data:34 - Loading data from /Users/theopenguino/Downloads/aiip5-Er-Qi-Yang-227J/data/agri.db
# Loading data from /Users/theopenguino/Downloads/aiip5-Er-Qi-Yang-227J/data/agri.db
# 2025-03-15 00:04:18.841 | INFO     | data_loader:load_data:58 - Data loaded successfully with shape: (57489, 15)
# 2025-03-15 00:04:18.841 | DEBUG    | data_loader:load_data:59 - Columns in data: ['System Location Code', 'Previous Cycle Plant Type', 'Plant Type', 'Plant Stage', 'Temperature Sensor (°C)', 'Humidity Sensor (%)', 'Light Intensity Sensor (lux)', 'CO2 Sensor (ppm)', 'EC Sensor (dS/m)', 'O2 Sensor (ppm)', 'Nutrient N Sensor (ppm)', 'Nutrient P Sensor (ppm)', 'Nutrient K Sensor (ppm)', 'pH Sensor', 'Water Level Sensor (mm)']
# 2025-03-15 00:04:18.842 | INFO     | main_process:process_data:28 - Cleaning data
# ...
